# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import pathlib
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds

# %%
data_dir_train=pathlib.WindowsPath("C:/Users/NitroPC/Documents/Python/ConcursoModelizacion/ConcursoModelizacion/Resource/data/train")
train_images=list(data_dir_train.glob('*/*.png'))
data_dir_test=pathlib.WindowsPath("C:/Users/NitroPC/Documents/Python/ConcursoModelizacion/ConcursoModelizacion/Resource/data/test")
test_images=list(data_dir_test.glob('*/*.png'))
print(len(train_images),len(test_images))
# Out:
# 28657 7178

# %%
im=PIL.Image.open(str(train_images[0]))
plt.imshow(im)

# %%
batch_size=32
img_height=48
img_width=48

# %%
names=['angry','disgusted','fearful','happy','neutral','sad','suprised']

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 28657 files belonging to 7 classes.
# Using 22926 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7178 files belonging to 7 classes.
# Using 1435 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 48, 48, 3)
# (32,)

# %%
from tensorflow.keras import layers

normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.003921569 0.8941177

# %%
num_classes = 7

model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=100
)
# Out:
# Epoch 1/100
# 718/718 [==============================] - 569s 792ms/step - loss: 1.7867 - accuracy: 0.2633 - val_loss: 1.5094 - val_accuracy: 0.4118
# Epoch 2/100
# 718/718 [==============================] - 25s 34ms/step - loss: 1.5074 - accuracy: 0.4246 - val_loss: 1.4134 - val_accuracy: 0.4557
# Epoch 3/100
# 718/718 [==============================] - 25s 34ms/step - loss: 1.3750 - accuracy: 0.4766 - val_loss: 1.3174 - val_accuracy: 0.4892
# Epoch 4/100
# 718/718 [==============================] - 25s 34ms/step - loss: 1.2915 - accuracy: 0.5078 - val_loss: 1.2820 - val_accuracy: 0.4955
# Epoch 5/100
# 718/718 [==============================] - 25s 34ms/step - loss: 1.2334 - accuracy: 0.5296 - val_loss: 1.2964 - val_accuracy: 0.5066
# Epoch 6/100
# 718/718 [==============================] - 25s 34ms/step - loss: 1.1785 - accuracy: 0.5492 - val_loss: 1.2546 - val_accuracy: 0.5233
# Epoch 7/100
# 718/718 [==============================] - 25s 34ms/step - loss: 1.1255 - accuracy: 0.5725 - val_loss: 1.2283 - val_accuracy: 0.5310
# Epoch 8/100
# 718/718 [==============================] - 26s 35ms/step - loss: 1.0688 - accuracy: 0.5984 - val_loss: 1.2647 - val_accuracy: 0.5247
# Epoch 9/100
# 718/718 [==============================] - 25s 35ms/step - loss: 1.0213 - accuracy: 0.6173 - val_loss: 1.3160 - val_accuracy: 0.5338
# Epoch 10/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.9674 - accuracy: 0.6373 - val_loss: 1.3392 - val_accuracy: 0.5247
# Epoch 11/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.9190 - accuracy: 0.6540 - val_loss: 1.4354 - val_accuracy: 0.5178
# Epoch 12/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.8711 - accuracy: 0.6759 - val_loss: 1.4547 - val_accuracy: 0.5199
# Epoch 13/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.8302 - accuracy: 0.6930 - val_loss: 1.5495 - val_accuracy: 0.5080
# Epoch 14/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.7837 - accuracy: 0.7082 - val_loss: 1.5718 - val_accuracy: 0.5066
# Epoch 15/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.7374 - accuracy: 0.7262 - val_loss: 1.6469 - val_accuracy: 0.5052
# Epoch 16/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.6977 - accuracy: 0.7437 - val_loss: 1.7688 - val_accuracy: 0.4997
# Epoch 17/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.6530 - accuracy: 0.7535 - val_loss: 1.8002 - val_accuracy: 0.5094
# Epoch 18/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.6078 - accuracy: 0.7761 - val_loss: 1.9451 - val_accuracy: 0.4885
# Epoch 19/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.5800 - accuracy: 0.7868 - val_loss: 1.9910 - val_accuracy: 0.4969
# Epoch 20/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.5399 - accuracy: 0.8017 - val_loss: 2.1518 - val_accuracy: 0.4906
# Epoch 21/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.5086 - accuracy: 0.8134 - val_loss: 2.2105 - val_accuracy: 0.4878
# Epoch 22/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.4728 - accuracy: 0.8239 - val_loss: 2.4761 - val_accuracy: 0.4808
# Epoch 23/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.4550 - accuracy: 0.8355 - val_loss: 2.5645 - val_accuracy: 0.4732
# Epoch 24/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.4308 - accuracy: 0.8459 - val_loss: 2.7484 - val_accuracy: 0.4662
# Epoch 25/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.4218 - accuracy: 0.8436 - val_loss: 2.6979 - val_accuracy: 0.4836
# Epoch 26/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.3820 - accuracy: 0.8622 - val_loss: 2.8579 - val_accuracy: 0.4857
# Epoch 27/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.3497 - accuracy: 0.8724 - val_loss: 3.0197 - val_accuracy: 0.4774
# Epoch 28/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.3561 - accuracy: 0.8660 - val_loss: 3.1468 - val_accuracy: 0.4732
# Epoch 29/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.3369 - accuracy: 0.8768 - val_loss: 3.2142 - val_accuracy: 0.4780
# Epoch 30/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.3160 - accuracy: 0.8837 - val_loss: 3.3503 - val_accuracy: 0.4725
# Epoch 31/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2986 - accuracy: 0.8907 - val_loss: 3.4968 - val_accuracy: 0.4711
# Epoch 32/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2982 - accuracy: 0.8915 - val_loss: 3.5911 - val_accuracy: 0.4676
# Epoch 33/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2798 - accuracy: 0.8954 - val_loss: 3.8263 - val_accuracy: 0.4697
# Epoch 34/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2740 - accuracy: 0.9027 - val_loss: 3.8356 - val_accuracy: 0.4774
# Epoch 35/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2650 - accuracy: 0.9006 - val_loss: 3.9652 - val_accuracy: 0.4711
# Epoch 36/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2520 - accuracy: 0.9065 - val_loss: 4.1010 - val_accuracy: 0.4780
# Epoch 37/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2429 - accuracy: 0.9093 - val_loss: 4.2041 - val_accuracy: 0.4746
# Epoch 38/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2376 - accuracy: 0.9110 - val_loss: 4.4657 - val_accuracy: 0.4537
# Epoch 39/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2425 - accuracy: 0.9110 - val_loss: 4.5131 - val_accuracy: 0.4634
# Epoch 40/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2186 - accuracy: 0.9218 - val_loss: 4.6101 - val_accuracy: 0.4774
# Epoch 41/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2149 - accuracy: 0.9201 - val_loss: 4.7002 - val_accuracy: 0.4794
# Epoch 42/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2140 - accuracy: 0.9219 - val_loss: 5.0102 - val_accuracy: 0.4801
# Epoch 43/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2237 - accuracy: 0.9179 - val_loss: 4.6885 - val_accuracy: 0.4739
# Epoch 44/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2039 - accuracy: 0.9263 - val_loss: 4.9880 - val_accuracy: 0.4774
# Epoch 45/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1914 - accuracy: 0.9320 - val_loss: 5.0614 - val_accuracy: 0.4725
# Epoch 46/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1770 - accuracy: 0.9360 - val_loss: 5.3570 - val_accuracy: 0.4815
# Epoch 47/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.2020 - accuracy: 0.9260 - val_loss: 5.2750 - val_accuracy: 0.4774
# Epoch 48/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1890 - accuracy: 0.9301 - val_loss: 5.3457 - val_accuracy: 0.4808
# Epoch 49/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1832 - accuracy: 0.9339 - val_loss: 5.4657 - val_accuracy: 0.4739
# Epoch 50/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1849 - accuracy: 0.9342 - val_loss: 5.5103 - val_accuracy: 0.4767
# Epoch 51/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1812 - accuracy: 0.9341 - val_loss: 5.7756 - val_accuracy: 0.4739
# Epoch 52/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1636 - accuracy: 0.9400 - val_loss: 5.8927 - val_accuracy: 0.4732
# Epoch 53/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1614 - accuracy: 0.9388 - val_loss: 5.8789 - val_accuracy: 0.4774
# Epoch 54/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1825 - accuracy: 0.9343 - val_loss: 5.8588 - val_accuracy: 0.4767
# Epoch 55/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1566 - accuracy: 0.9446 - val_loss: 6.2521 - val_accuracy: 0.4753
# Epoch 56/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1836 - accuracy: 0.9341 - val_loss: 6.2751 - val_accuracy: 0.4725
# Epoch 57/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1738 - accuracy: 0.9405 - val_loss: 5.8912 - val_accuracy: 0.4815
# Epoch 58/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1498 - accuracy: 0.9480 - val_loss: 6.2965 - val_accuracy: 0.4801
# Epoch 59/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1560 - accuracy: 0.9471 - val_loss: 6.2844 - val_accuracy: 0.4732
# Epoch 60/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1661 - accuracy: 0.9435 - val_loss: 6.2729 - val_accuracy: 0.4753
# Epoch 61/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1498 - accuracy: 0.9455 - val_loss: 6.3980 - val_accuracy: 0.4704
# Epoch 62/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1413 - accuracy: 0.9500 - val_loss: 6.3247 - val_accuracy: 0.4857
# Epoch 63/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1643 - accuracy: 0.9422 - val_loss: 6.3626 - val_accuracy: 0.4808
# Epoch 64/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1453 - accuracy: 0.9474 - val_loss: 6.2787 - val_accuracy: 0.4864
# Epoch 65/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1502 - accuracy: 0.9467 - val_loss: 6.6346 - val_accuracy: 0.4829
# Epoch 66/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1520 - accuracy: 0.9475 - val_loss: 6.5619 - val_accuracy: 0.4815
# Epoch 67/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1523 - accuracy: 0.9486 - val_loss: 6.7175 - val_accuracy: 0.4955
# Epoch 68/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1344 - accuracy: 0.9535 - val_loss: 6.8128 - val_accuracy: 0.4753
# Epoch 69/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1550 - accuracy: 0.9496 - val_loss: 7.0190 - val_accuracy: 0.4815
# Epoch 70/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1354 - accuracy: 0.9530 - val_loss: 6.9246 - val_accuracy: 0.4997
# Epoch 71/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1694 - accuracy: 0.9428 - val_loss: 6.6438 - val_accuracy: 0.4871
# Epoch 72/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1514 - accuracy: 0.9471 - val_loss: 6.8057 - val_accuracy: 0.4948
# Epoch 73/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1260 - accuracy: 0.9584 - val_loss: 6.9895 - val_accuracy: 0.4913
# Epoch 74/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1433 - accuracy: 0.9520 - val_loss: 6.7628 - val_accuracy: 0.4920
# Epoch 75/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1212 - accuracy: 0.9574 - val_loss: 6.9264 - val_accuracy: 0.4962
# Epoch 76/100
# 718/718 [==============================] - 26s 37ms/step - loss: 0.1391 - accuracy: 0.9503 - val_loss: 7.2527 - val_accuracy: 0.4718
# Epoch 77/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.1375 - accuracy: 0.9541 - val_loss: 6.8862 - val_accuracy: 0.4829
# Epoch 78/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1306 - accuracy: 0.9563 - val_loss: 7.0950 - val_accuracy: 0.4871
# Epoch 79/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1567 - accuracy: 0.9485 - val_loss: 7.3832 - val_accuracy: 0.4767
# Epoch 80/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1451 - accuracy: 0.9508 - val_loss: 7.1263 - val_accuracy: 0.4871
# Epoch 81/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.1255 - accuracy: 0.9592 - val_loss: 7.1045 - val_accuracy: 0.4794
# Epoch 82/100
# 718/718 [==============================] - 25s 35ms/step - loss: 0.1219 - accuracy: 0.9588 - val_loss: 7.2533 - val_accuracy: 0.4920
# Epoch 83/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1103 - accuracy: 0.9637 - val_loss: 7.2208 - val_accuracy: 0.4857
# Epoch 84/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1295 - accuracy: 0.9570 - val_loss: 7.4956 - val_accuracy: 0.4808
# Epoch 85/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1441 - accuracy: 0.9525 - val_loss: 7.5537 - val_accuracy: 0.4836
# Epoch 86/100
# 718/718 [==============================] - 24s 34ms/step - loss: 0.1296 - accuracy: 0.9561 - val_loss: 7.4657 - val_accuracy: 0.4746
# Epoch 87/100
# 718/718 [==============================] - 24s 34ms/step - loss: 0.1236 - accuracy: 0.9574 - val_loss: 7.6572 - val_accuracy: 0.4746
# Epoch 88/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1264 - accuracy: 0.9591 - val_loss: 7.2923 - val_accuracy: 0.4983
# Epoch 89/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1356 - accuracy: 0.9534 - val_loss: 7.6005 - val_accuracy: 0.4815
# Epoch 90/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1057 - accuracy: 0.9645 - val_loss: 7.5447 - val_accuracy: 0.4871
# Epoch 91/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1238 - accuracy: 0.9581 - val_loss: 7.6585 - val_accuracy: 0.4794
# Epoch 92/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1231 - accuracy: 0.9603 - val_loss: 7.7418 - val_accuracy: 0.4934
# Epoch 93/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1189 - accuracy: 0.9607 - val_loss: 7.8332 - val_accuracy: 0.4871
# Epoch 94/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1058 - accuracy: 0.9630 - val_loss: 7.9100 - val_accuracy: 0.4927
# Epoch 95/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1189 - accuracy: 0.9587 - val_loss: 7.8720 - val_accuracy: 0.4753
# Epoch 96/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.0951 - accuracy: 0.9694 - val_loss: 7.9180 - val_accuracy: 0.4850
# Epoch 97/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.0976 - accuracy: 0.9672 - val_loss: 7.8945 - val_accuracy: 0.4815
# Epoch 98/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1325 - accuracy: 0.9594 - val_loss: 8.3441 - val_accuracy: 0.4746
# Epoch 99/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1071 - accuracy: 0.9644 - val_loss: 8.2306 - val_accuracy: 0.4578
# Epoch 100/100
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1266 - accuracy: 0.9608 - val_loss: 8.4110 - val_accuracy: 0.4739

# %%
tf.keras.models.save_model(
    model, 'C:/Users/NitroPC/Documents/Python/ConcursoModelizacion/ConcursoModelizacion/2. Dan/model/', overwrite=True, include_optimizer=True, save_format=None,
    signatures=None, options=None
)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:2338: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:1395: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '
# INFO:tensorflow:Assets written to: C:/Users/NitroPC/Documents/Python/ConcursoModelizacion/ConcursoModelizacion/2. Dan/model/assets

# %%
new_model=tf.keras.models.load_model('C:/Users/NitroPC/Documents/Python/ConcursoModelizacion/ConcursoModelizacion/2. Dan/model/')

# %%
new_model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=1
)
# Out:
# 718/718 [==============================] - 25s 34ms/step - loss: 0.1174 - accuracy: 0.9612 - val_loss: 8.3161 - val_accuracy: 0.4683
